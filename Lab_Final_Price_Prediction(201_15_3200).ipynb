# %% [markdown]
# <a href="https://colab.research.google.com/github/shaun-mia/HackerRank_Python_Solutions/blob/main/Lab_Final_Price_Prediction(201_15_3200).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Print 5 head :  )

# %%
df  = pd.read_csv("/content/Price prediction.csv")
df.head(5)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# # Data frame ☹

# %%
df  = pd.read_csv("/content/Price prediction.csv")
df.head(5)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.head(6)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
# 5   6             2012.667           7.1
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
# 5                              2175.03000                                3
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# ...

# %% [markdown]
# # Print Data frame information:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# Unit the last coloum

# %%
x= df.iloc[:,:-1].values 
x
# Out:
# array([[1.0000000e+00, 2.0129170e+03, 3.2000000e+01, ..., 1.0000000e+01,
#         2.4982980e+01, 1.2154024e+02],
#        [2.0000000e+00, 2.0129170e+03, 1.9500000e+01, ..., 9.0000000e+00,
#         2.4980340e+01, 1.2153951e+02],
#        [3.0000000e+00, 2.0135830e+03, 1.3300000e+01, ..., 5.0000000e+00,
#         2.4987460e+01, 1.2154391e+02],
#        ...,
#        [4.1200000e+02, 2.0132500e+03, 1.8800000e+01, ..., 7.0000000e+00,
#         2.4979230e+01, 1.2153986e+02],
#        [4.1300000e+02, 2.0130000e+03, 8.1000000e+00, ..., 5.0000000e+00,
#         2.4966740e+01, 1.2154067e+02],
#        [4.1400000e+02, 2.0135000e+03, 6.5000000e+00, ..., 9.0000000e+00,
#         2.4974330e+01, 1.2154310e+02]])

# %%
y= df.iloc[:,3].values 
y
# Out:
# array([  84.87882,  306.5947 ,  561.9845 ,  561.9845 ,  390.5684 ,
#        2175.03   ,  623.4731 ,  287.6025 , 5512.038  , 1783.18   ,
#         405.2134 ,   90.45606,  492.2313 , 2469.645  , 1164.838  ,
#         579.2083 ,  292.9978 ,  350.8515 ,  368.1363 ,   23.38284,
#        2275.877  ,  279.1726 , 1360.139  ,  279.1726 ,  480.6977 ,
#        1487.868  ,  383.8624 ,  276.449  ,  557.478  ,  451.2438 ,
#        4519.69   ,  769.4034 ,  488.5727 ,  323.655  ,  205.367  ,
#        4079.418  , 1935.009  , 1360.139  ,  577.9615 ,  289.3248 ,
#        4082.015  , 4066.587  ,  519.4617 ,  512.7871 ,  533.4762 ,
#         488.8193 ,  463.9623 ,  640.7391 , 4605.749  , 4510.359  ,
#         512.5487 , 1758.406  , 1438.579  ,  492.2313 ,  289.3248 ,
#        1160.632  ,  371.2495 ,   56.47425, 4510.359  ,  336.0532 ,
#        1931.207  ,  259.6607 , 2175.877  ,  533.4762 ,  995.7554 ,
#         123.7429 ,  193.5845 ,  104.8101 ,  464.223  ,  561.9845 ,
# ...

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size= 0.2, random_state=2)

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
score = reg.score(x_test,y_test)*100
print("Accacy obtained by Logistic regression :",score)
# Out:
# Accacy obtained by Logistic regression : 100.0
